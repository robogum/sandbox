# %% [markdown]
# Serp apiを使用には、Serp apiでアカウントを作成します。
# Serp apiのページにログインすると、APIKEYをコピーできるようになります。
# そのAPIKEYを、「searchbook/.env」ファイルの中に設定します。
# （searchbook/.env.exampleを参照して作成します。）

# %%
# このセルを実行すると、book_titleをSerp apiで検索します。
from searchbook.search_apis import get_book_price_serpapi

book_title = "Jupyter Notebook"
results = get_book_price_serpapi(book_title)
results
# Out:
# [{'title': 'The Jupyter Notebookの価格（料金・費用）',
#   'link': 'https://www.itreview.jp/products/the-jupyter-notebook/price',
#   'snippet': 'The Jupyter Notebookの無料プランを含めたプランごとの月額・年額での価格（料金・費用）を紹介中！導入メリットや価格、特徴的な機能など最新のユーザーレビューや ...'},
#  {'title': '【楽天市場】jupyter notebookの通販',
#   'link': 'https://search.rakuten.co.jp/search/mall/jupyter+notebook/',
#   'snippet': '「jupyter notebook」439件. San Kyu Shop 中古 【中古】 Jupyter Notebook … 中古品-良い 1,245円(価格+送料) 847円 +送料398円 7ポイント(1倍)'},
#  {'title': 'PythonユーザのためのJupyter[実践]入門 | 池内 孝啓, 片柳 ...',
#   'link': 'https://www.amazon.co.jp/Python%E3%83%A6%E3%83%BC%E3%82%B6%E3%81%AE%E3%81%9F%E3%82%81%E3%81%AEJupyter-%E5%AE%9F%E8%B7%B5-%E5%85%A5%E9%96%80-%E6%B1%A0%E5%86%85-%E5%AD%9D%E5%95%93/dp/4774192236',
#   'snippet': '新品. ￥2,908￥2,908 税込. 無料配送 9月29日 火曜日にお届け. 発送元: 松陰 書店. 販売者: 松陰 書店 · 中古 - 非常に良い. ￥191￥191 税込. 配送料 ¥300 9月16日-17日に ...'},
#  {'title': 'Jupyter Notebook系SaaS製品の比較',
#   'link': 'https://cam-inc.co.jp/p/techblog/734335523711091798',
# ...
