# %%
from searchbook import searchbook


isbn = "9784478016268"
#results = searchbook(isbn, "valueserp")
results = searchbook(isbn, "scrape_do")
results
# Out:
# [{'title': '【楽天市場】采配の通販',
#   'link': 'https://search.rakuten.co.jp/search/mall/%E9%87%87%E9%85%8D/',
#   'snippet': '【中古】采配. San Kyu Shop. 中古. 【中古】采配. 中古品-非常に良い. 366円. 送料無料. 3ポイント(1倍). 最短24時間以内に出荷(日曜除く). ブックサプライ. 同じ商品を ...'},
#  {'title': '采配 中古本・書籍 | ブックオフ公式オンラインストア',
#   'link': 'https://shopping.bookoff.co.jp/used/0016740666',
#   'snippet': '【定価88%OFF】中古価格 220円(税込)【1760円おトク！】「采配」落合博満(著者)の中古商品ページです。1800円以上のご注文で送料無料。'},
#  {'title': '「采配」の落札相場・落札価格 - Yahoo!オークション',
#   'link': 'https://auctions.yahoo.co.jp/closedsearch/closedsearch/%E9%87%87%E9%85%8D/0',
#   'snippet': '「采配」関連の新品・未使用品・中古品の過去120日分の落札相場をYahoo!オークションで確認できます。約153件の落札価格は平均10747です。Yahoo!'},
#  {'title': 'すべては宇宙の采配: 中古 | 木村秋則 | 古本の通販ならネットオフ',
#   'link': 'https://www.netoff.co.jp/detail/0010923686/',
#   'snippet': 'すべては宇宙の采配/単行本 · 販売価格 550円. －. 買取価格 440円 · ＝ 差引. 110 円. プレミアム会員とは · クーポン. お得！10点 ...'},
#  {'title': 'コーエー 采配のゆくえ',
#   'link': 'https://kakaku.com/item/41384011225/',
# ...
