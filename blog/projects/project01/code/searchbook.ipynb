# %% [markdown]
# ISBNで、Google検索を行い結果を表示します。

# %%
from searchbook import searchbook


isbn = "9784478016268"
results = None

# 使用するサービスのコメントを解除してください。

#results = searchbook(isbn, "valueserp")
#results = searchbook(isbn, "scrape_do")
results = searchbook(isbn, "serpapi")

results
