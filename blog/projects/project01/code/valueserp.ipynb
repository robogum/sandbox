# %% [markdown]
# VALUE SERPを使用して検索する
# アカウントを作成して、ページにログインすると、APIKEYをコピーできるようになります。
# そのAPIKEYを、「.env」ファイルの中に設定します。
# （.env.exampleを参照して作成します。）

# %%
# %pip install python-dotenv requests

# %%
from pathlib import Path
from dotenv import load_dotenv
import requests
import json
import os

# このノートブックと同じ code/ にある .env を読む
load_dotenv(Path.cwd() / ".env")
load_dotenv(Path.cwd() / "blog/projects/project01/code/.env")

def get_book_price_valueserp(book_title):
    api_key = os.getenv("VALUESERP_API_KEY")
    if not api_key:
        print('".env" を設定してください。".env.example"を参照')
        return

    params = {
        'api_key': api_key,
        'q': f'{book_title} 中古 価格',
        'gl': 'jp',
        'hl': 'ja',
        'google_domain': 'google.co.jp',
    }

    url = "https://api.valueserp.com/search"
    response = requests.get(url, params=params)
    data = response.json()

    organic_results = data.get('organic_results', [])
    if not organic_results:
        print("No results found.")
        return []

    for result in organic_results:
        title = result.get('title', '')
        link = result.get('link', '')
        snippet = result.get('snippet', '')

        print(f"Title: {title}")
        print(f"Link: {link}")
        print(f"Snippet: {snippet}\n")

    return organic_results

# %%
# 実行セル（input は使わない。タイトルを書き換えて実行）
book_title = "新詳説DTP基礎"
get_book_price_valueserp(book_title)
# Out:
# Title: 新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS)
# Link: https://www.amazon.co.jp/%E6%96%B0%E8%A9%B3%E8%AA%ACDTP%E5%9F%BA%E7%A4%8E-%E6%94%B9%E8%A8%82%E5%9B%9B%E7%89%88-MdN-DESIGN-BASICS/dp/4844364766
# Snippet: 新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS). 4.1 5つ星のうち4.1 (15). 新 ... Amazonの他の出品者Amazonの他の出品者. 最低価格: 中古商品. ￥413 ￥413. + ￥257 ...
#
# Title: 【楽天市場】新詳説dtp基礎の通販
# Link: https://search.rakuten.co.jp/search/mall/%E6%96%B0%E8%A9%B3%E8%AA%ACdtp%E5%9F%BA%E7%A4%8E/
# Snippet: 【中古】 新詳説DTP基礎改訂3版 / 波多江潤子 / エムディエヌコーポレーション [単行本]【メール便送料無料】【最短翌日配達対応】. 中古品-良い. 505円. 送料無料.
#
# Title: 新詳説DTP基礎 中古本・書籍
# Link: https://shopping.bookoff.co.jp/used/0016784416
# Snippet: 【定価92%OFF】中古価格 220円(税込)【2530円おトク！】「新詳説DTP基礎」波多江潤子【著】の中古商品ページです。1800円以上のご注文で送料無料。
#
# Title: 新詳説DTP基礎 改訂四版 - MdN BOOKS
# Link: https://books.mdn.co.jp/books/3214303024/
# Snippet: 2015/02/03 — 新詳説DTP基礎 改訂四版. 波多江 潤子 著. 定価 2,750円 （本体 2,500円＋税10%） ※電子書籍の価格は各販売ストアにてご確認ください｡
#
# Title: 新詳説 DTP基礎 改訂4版 インプレス
# Link: https://www.biccamera.com/bc/item/6722555/?srsltid=AfmBOoqLZnM-Gvw3ZDl_NC4q1UyRZXkd-_QV-uaYJ7O5VTq4POgfzAen
# Snippet: ... 制作にも対応！！ 詳細. 価格. 2,750円（税込）. ポイント, 83ポイント （83円相当）. 販売休止中です. お届け先を変更する. カートに入れる. 店舗に取り置く（在庫・展示一覧）.
#
# Title: 新詳説DTP基礎 - メルカリ
# Link: https://jp.mercari.com/item/m66870715462?srsltid=AfmBOoqBim_X3RjEs33Ke1MGq0z_Fl5OJoEWVswPZQ4v5-IY41f21TFt
# Snippet: 【中古】単行本(実用) ≪コンピュータ≫ 新詳説 DTP基礎 改訂版. ¥300. 【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 /. ¥555. TPP不参加戸別所得補償 ...
#
# Title: 新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS)
# Link: https://item.fril.jp/1d608037c7e7fb019f44f3ca4e6c8a49
# Snippet: 新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS). ¥803 送料込. 楽天の審査を経た ...
#
# Title: 【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 ...
# Link: https://wowma.jp/item/527669803
# Snippet: 商品名:【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 / エムディエヌコーポレーション [単行本]【メール便送料無料】 著者：波多江 潤子出版社：エムディ ...
#
# Title: 新詳説DTP基礎 / 波多江 潤子【著】
# Link: https://www.kinokuniya.co.jp/f/dsg-01-9784844357117
# Snippet: DTPをはじめる人の標準テキストブック！ 導入から印刷・編集、制作・出力までのイロハを完全図解！！ 本書は、DTPの導入から印刷・編集、制作・出力まで、DTP初心者に必要 ...
# [{'position': 1,
#   'block_position': 1,
#   'title': '新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS)',
#   'link': 'https://www.amazon.co.jp/%E6%96%B0%E8%A9%B3%E8%AA%ACDTP%E5%9F%BA%E7%A4%8E-%E6%94%B9%E8%A8%82%E5%9B%9B%E7%89%88-MdN-DESIGN-BASICS/dp/4844364766',
#   'domain': 'www.amazon.co.jp',
#   'displayed_link': 'https://www.amazon.co.jp › 新詳説DTP基礎-改訂四版-...',
#   'snippet': '新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS). 4.1 5つ星のうち4.1 (15). 新 ... Amazonの他の出品者Amazonの他の出品者. 最低価格: 中古商品. ￥413 ￥413. + ￥257 ...',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'price': 4.1,
#      'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥421', '在庫あり', '4.1(15)']}}},
#  {'position': 2,
#   'block_position': 2,
#   'title': '【楽天市場】新詳説dtp基礎の通販',
#   'link': 'https://search.rakuten.co.jp/search/mall/%E6%96%B0%E8%A9%B3%E8%AA%ACdtp%E5%9F%BA%E7%A4%8E/',
#   'domain': 'search.rakuten.co.jp',
#   'displayed_link': 'https://search.rakuten.co.jp › search › mall › 新詳説dtp...',
#   'snippet': '【中古】 新詳説DTP基礎改訂3版 / 波多江潤子 / エムディエヌコーポレーション [単行本]【メール便送料無料】【最短翌日配達対応】. 中古品-良い. 505円. 送料無料.',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {},
#     'extensions': ['4.8&nbsp;店舗の評価&nbsp;(2224)']}}},
#  {'position': 3,
#   'block_position': 3,
#   'title': '新詳説DTP基礎 中古本・書籍',
#   'link': 'https://shopping.bookoff.co.jp/used/0016784416',
#   'domain': 'shopping.bookoff.co.jp',
#   'displayed_link': 'https://shopping.bookoff.co.jp › used',
#   'snippet': '【定価92%OFF】中古価格 220円(税込)【2530円おトク！】「新詳説DTP基礎」波多江潤子【著】の中古商品ページです。1800円以上のご注文で送料無料。',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥220', '在庫あり']}}},
#  {'position': 4,
#   'block_position': 4,
#   'title': '新詳説DTP基礎 改訂四版 - MdN BOOKS',
#   'link': 'https://books.mdn.co.jp/books/3214303024/',
#   'domain': 'books.mdn.co.jp',
#   'displayed_link': 'https://books.mdn.co.jp › books',
#   'snippet': '2015/02/03 — 新詳説DTP基礎 改訂四版. 波多江 潤子 著. 定価 2,750円 （本体 2,500円＋税10%） ※電子書籍の価格は各販売ストアにてご確認ください｡',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'price': 2500,
#      'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥2,500']}},
#   'date': '2015/02/03',
#   'date_utc': '2015-02-03T00:00:00.000Z'},
#  {'position': 5,
#   'block_position': 5,
#   'title': '新詳説 DTP基礎 改訂4版 インプレス',
#   'link': 'https://www.biccamera.com/bc/item/6722555/?srsltid=AfmBOoqLZnM-Gvw3ZDl_NC4q1UyRZXkd-_QV-uaYJ7O5VTq4POgfzAen',
#   'domain': 'www.biccamera.com',
#   'displayed_link': 'https://www.biccamera.com › ... › 書籍 › パソコン書籍',
#   'snippet': '... 制作にも対応！！ 詳細. 価格. 2,750円（税込）. ポイント, 83ポイント （83円相当）. 販売休止中です. お届け先を変更する. カートに入れる. 店舗に取り置く（在庫・展示一覧）.',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥2,750', '在庫なし']}}},
#  {'position': 6,
#   'block_position': 6,
#   'title': '新詳説DTP基礎 - メルカリ',
#   'link': 'https://jp.mercari.com/item/m66870715462?srsltid=AfmBOoqBim_X3RjEs33Ke1MGq0z_Fl5OJoEWVswPZQ4v5-IY41f21TFt',
#   'domain': 'jp.mercari.com',
#   'displayed_link': 'https://jp.mercari.com › ... › 本 › コンピュータ・IT',
#   'snippet': '【中古】単行本(実用) ≪コンピュータ≫ 新詳説 DTP基礎 改訂版. ¥300. 【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 /. ¥555. TPP不参加戸別所得補償 ...',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥500', '在庫あり']}}},
#  {'position': 7,
#   'block_position': 7,
#   'title': '新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS)',
#   'link': 'https://item.fril.jp/1d608037c7e7fb019f44f3ca4e6c8a49',
#   'domain': 'item.fril.jp',
#   'displayed_link': 'https://item.fril.jp › ... › 本 › 語学/参考書',
#   'snippet': '新詳説DTP基礎 改訂四版 (MdN DESIGN BASICS). ¥803 送料込. 楽天の審査を経た ...',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥791', '在庫あり']}}},
#  {'position': 8,
#   'block_position': 8,
#   'title': '【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 ...',
#   'link': 'https://wowma.jp/item/527669803',
#   'domain': 'wowma.jp',
#   'displayed_link': 'https://wowma.jp › ... › その他本・コミック・雑誌',
#   'snippet': '商品名:【中古】 新詳説 DTP基礎 （MdN design basics） / 波多江 潤子 / エムディエヌコーポレーション [単行本]【メール便送料無料】 著者：波多江 潤子出版社：エムディ ...',
#   'prerender': False,
#   'rich_snippet': {'top': {'detected_extensions': {'price': 543,
#      'symbol': '¥',
#      'currency': {'name': 'Japanese Yen', 'code': 'JPY', 'symbol': '¥'}},
#     'extensions': ['￥543']}}},
#  {'position': 9,
#   'block_position': 9,
#   'title': '新詳説DTP基礎 / 波多江 潤子【著】',
#   'link': 'https://www.kinokuniya.co.jp/f/dsg-01-9784844357117',
#   'domain': 'www.kinokuniya.co.jp',
#   'displayed_link': 'https://www.kinokuniya.co.jp › dsg-01-9784844357117',
#   'snippet': 'DTPをはじめる人の標準テキストブック！ 導入から印刷・編集、制作・出力までのイロハを完全図解！！ 本書は、DTPの導入から印刷・編集、制作・出力まで、DTP初心者に必要 ...',
#   'prerender': False}]
