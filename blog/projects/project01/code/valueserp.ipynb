# %% [markdown]
# VALUE SERPを使用するには、VALUE SERPでアカウントを作成します。
# VALUE SERPのページにログインすると、APIKEYをコピーできるようになります。
# そのAPIKEYを、「searchbook/.env」ファイルの中に設定します。
# （searchbook/.env.exampleを参照して作成します。）

# %%
# このセルを実行すると、book_titleをVALUE SERPで検索します。
from searchbook.search_apis import get_book_price_valueserp

book_title = "Jupyter Notebook"
results = get_book_price_valueserp(book_title)
results
