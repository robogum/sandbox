# %% [markdown]
# scrape.do を使用して検索するには、
# scrape.doでアカウントを作成します。
# scrape.doのページにログインすると、token をコピーできるようになります。
# その token を、「searchbook/.env」ファイルの中に設定します。
# （searchbook/.env.exampleを参照して作成します。）

# %%
# このセルを実行すると、book_titleをscrape.doで検索します。
from searchbook.search_apis import get_book_price_scrape_do

book_title = "Jupyter Notebook"
results = get_book_price_scrape_do(book_title)
results
# Out:
# [{'title': 'The Jupyter Notebookの価格（料金・費用）',
#   'link': 'https://www.google.co.jp/goto?url=CAEScwHrOzAVvHvnkx9i3Oi6Umh4SC3i7mh17dWuWtiQgmLSrvC3OrEtRj7JQNh-KwEj6AxR8L7AAWKKUWDhblB0OguoY5J9IRTyP7OSe2K5nO09Y4-BQSTPZsYzlygfxLOkewHWB1rhPQzCeAcFdNKBx8owtpk',
#   'snippet': 'The Jupyter Notebookの無料プランを含めたプランごとの月額・年額での価格（料金・費用）を紹介中！導入メリットや価格、特徴的な機能など最新のユーザーレビューや ...'},
#  {'title': 'Jupyter Notebookで始めるプログラミング 中古本・書籍',
#   'link': 'https://www.google.co.jp/goto?url=CAESZgHrOzAVkPWLz6sWKQVEIq1g3QldfUTM4cj6vLHmj-fTsBO6NLFo1BxIMhaRKGAL8pap1PTSsCtWlrR-lTZeORs2m_9v0sf0cSliUk8_Zfl8EkPKhTL-8kijDbfNVoOdnvUNeZMkQg',
#   'snippet': '【定価63%OFF】中古価格 770円(税込)【1320円おトク！】「Jupyter Notebookで始めるプログラミング」桑田喜隆(著者),小川祐紀雄(著者),早坂成人(著者),石坂徹(著者)の ...'},
#  {'title': '【楽天市場】jupyter notebookの通販',
#   'link': 'https://www.google.co.jp/goto?url=CAEScgHrOzAV1r3oJnIY1lQC7GkvAl4AHiGDRpulx92Omrfg0Z4V3t8BZUOsnkP7-0QshWqMabFOEvRny0g_ntLPClA4jAMFBLlbvlhU1EBVApTr3nbDiDKR7o2aW3tsF5nupNDNhC54z2s94XGpb3kIlhcH5Q',
# ...
