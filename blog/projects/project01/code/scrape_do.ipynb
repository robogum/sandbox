# %% [markdown]
# scrape.do を使用して検索する
# アカウントを作成して、ページにログインすると、token をコピーできるようになります。
# その token を、「.env」ファイルの中に設定します。
# （.env.exampleを参照して作成します。）

# %%
# %pip install python-dotenv requests

# %%
from search_apis import get_book_price_scrape_do

# %%
# 実行セル（input は使わない。タイトルを書き換えて実行）
book_title = "新詳説DTP基礎"
results = get_book_price_scrape_do(book_title)
results
